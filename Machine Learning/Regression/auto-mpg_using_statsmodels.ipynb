# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
df = pd.read_csv("auto-mpg.csv")
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 393  27.0          4         140.0         86    2790          15.6    82
# 394  44.0          4          97.0         52    2130          24.6    82
# 395  32.0          4         135.0         84    2295          11.6    82
# 396  28.0          4         120.0         79    2625          18.6    82
# 397  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   year          398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# Seems to be issue with horsepower column. Its dtype is object. Need to delete those record and also update the dtype to numeric
df = df[df['horsepower'] != '?']

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
#  8   name          392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 30.6+ KB
# C:\Users\Tejas Patil\AppData\Local\Temp\ipykernel_18232\2901941260.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
x = df[['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'year', 'origin']]
x
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  year  origin
# 0            8         307.0         130    3504          12.0    70       1
# 1            8         350.0         165    3693          11.5    70       1
# 2            8         318.0         150    3436          11.0    70       1
# 3            8         304.0         150    3433          12.0    70       1
# 4            8         302.0         140    3449          10.5    70       1
# ..         ...           ...         ...     ...           ...   ...     ...
# 393          4         140.0          86    2790          15.6    82       1
# 394          4          97.0          52    2130          24.6    82       2
# 395          4         135.0          84    2295          11.6    82       1
# 396          4         120.0          79    2625          18.6    82       1
# 397          4         119.0          82    2720          19.4    82       1
#
# [392 rows x 7 columns]

# %%
y = df[['mpg']]
y
# Out:
#       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 393  27.0
# 394  44.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [392 rows x 1 columns]

# %%
# Beta_zero column addition
X = sm.add_constant(x)
X
# Out:
#      const  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0      1.0          8         307.0         130    3504          12.0    70
# 1      1.0          8         350.0         165    3693          11.5    70
# 2      1.0          8         318.0         150    3436          11.0    70
# 3      1.0          8         304.0         150    3433          12.0    70
# 4      1.0          8         302.0         140    3449          10.5    70
# ..     ...        ...           ...         ...     ...           ...   ...
# 393    1.0          4         140.0          86    2790          15.6    82
# 394    1.0          4          97.0          52    2130          24.6    82
# 395    1.0          4         135.0          84    2295          11.6    82
# 396    1.0          4         120.0          79    2625          18.6    82
# 397    1.0          4         119.0          82    2720          19.4    82
#
#      origin
# 0         1
# 1         1
# 2         1
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 392 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   const         392 non-null    float64
#  1   cylinders     392 non-null    int64
#  2   displacement  392 non-null    float64
#  3   horsepower    392 non-null    int64
#  4   weight        392 non-null    int64
#  5   acceleration  392 non-null    float64
#  6   year          392 non-null    int64
#  7   origin        392 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 27.6 KB

# %%
# Seems to be issue with horsepower column. Its dtype is object. Need to delete this record

#X = X[X['horsepower'] != '?']

X
# Out:
#      const  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0      1.0          8         307.0         130    3504          12.0    70
# 1      1.0          8         350.0         165    3693          11.5    70
# 2      1.0          8         318.0         150    3436          11.0    70
# 3      1.0          8         304.0         150    3433          12.0    70
# 4      1.0          8         302.0         140    3449          10.5    70
# ..     ...        ...           ...         ...     ...           ...   ...
# 393    1.0          4         140.0          86    2790          15.6    82
# 394    1.0          4          97.0          52    2130          24.6    82
# 395    1.0          4         135.0          84    2295          11.6    82
# 396    1.0          4         120.0          79    2625          18.6    82
# 397    1.0          4         119.0          82    2720          19.4    82
#
#      origin
# 0         1
# 1         1
# 2         1
# ...

# %%
#X['horsepower'] = pd.to_numeric(X['horsepower'])
#X.info()

# %%
# build the model

model = sm.OLS(y, X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     252.4
# Date:                Fri, 29 Nov 2024   Prob (F-statistic):          2.04e-139
# Time:                        11:25:21   Log-Likelihood:                -1023.5
# No. Observations:                 392   AIC:                             2063.
# Df Residuals:                     384   BIC:                             2095.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...
